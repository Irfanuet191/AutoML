# %%
#Front end back end integration via flask by developing api
# !pip install flask-ngrok
# !pip install flask==0.12.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 83 kB 1.4 MB/s
# ...
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
# ...

# %%
# !pip install pyngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 761 kB 23.6 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.2.1-py3-none-any.whl size=19792 sha256=d9657cca95aed2b1ebb3ba07c5b9b1d463b0ffda160e25f91d0316b6d53547e6
#   Stored in directory: /root/.cache/pip/wheels/5d/f2/70/526da675d32f17577ec47ac4c663084efe39d47c826b6c3bb1
# Successfully built pyngrok
# ...

# %%
# !pip install flask_bootstrap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 456 kB 34.3 MB/s
# ...
#   Created wheel for flask-bootstrap: filename=Flask_Bootstrap-3.3.7.1-py3-none-any.whl size=460123 sha256=3b5f7be0c22d1b4d4bb54a3fba8c075a2d847fde5dd0d8f75067ea8cc8aeecaa
#   Stored in directory: /root/.cache/pip/wheels/f2/a3/85/fe8b65a65a447c9906e3b7edb7d9e6c74dfa9c8425c3dd3007
# ...
#   Created wheel for visitor: filename=visitor-0.1.3-py3-none-any.whl size=3943 sha256=3539321cba9de1587e7287e4e24108e989d0da14517249b0835c057060da6727
#   Stored in directory: /root/.cache/pip/wheels/d3/40/52/5dae7760434a82caf8b8f88323029188b2d4ea3ac1235e550a
# Successfully built flask-bootstrap visitor
# ...

# %%
# !pip install flask_wtf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 136 kB 44.7 MB/s
# ...

# %%
# !pip install wtforms
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from flask import Flask, render_template,request,jsonify 
from pyngrok import ngrok
from flask_bootstrap import Bootstrap
from flask_ngrok import run_with_ngrok

from flask_wtf import FlaskForm
from wtforms import StringField, SubmitField
from wtforms.validators import DataRequired

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
port_no = 5000
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(5000)"))
# Out:
# https://d3jimxw9c36-496ff2e9c6d22116-5000-colab.googleusercontent.com/

# %%
#CNN network development code 
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
import cv2
import glob
import PIL
import PIL.Image
import matplotlib.pyplot as plt

#DATASET USED IS CIFAR10
(dataTrain,dataTest),info=tfds.load('cifar10', split=['train','test'], with_info=True,as_supervised=True)

#Named automl for cnn network development class
class automl:
  
  def __init__(self):
    self.model1 =  keras.Sequential()
    self.test_data=None
    self.train_data=None
    self.model_history=None
   
  def add_layer_Input(self,shape_img=(32,32,3)):
     self.model1.add(keras.Input(shape=shape_img))
    
  def add_layer_MaxPooling2D(self,pool_size_kernal=(2,2)):
    self.model1.add(keras.layers.MaxPooling2D(pool_size=pool_size_kernal))

  def add_layer_Conv2D(self,filters=64,kernal_size=(3,3),activation_func='relu',padding_status='valid'):
     self.model1.add(keras.layers.Conv2D(filters,kernal_size,padding=padding_status,activation=activation_func))
  
  def add_layer_Flatten(self):
    self.model1.add(keras.layers.Flatten())
  
  def add_layer_Dense(self,neuronsNum=64,activation_func='relu'):
    self.model1.add(keras.layers.Dense(neuronsNum,activation=activation_func))
  
  def summary_model(self):
    self.model1.summary()

  def model_train_test(self,Batch_Size=64,Epoch_No=10):
    self.model1.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=keras.optimizers.Adam(learning_rate=3e-4),
    metrics=["accuracy"])
    self.history_Model=self.model1.fit(self.test_data,batch_size=64,epochs=10,verbose=2,validation_data=self.train_data)
    return self.history_Model.history['accuracy'],self.history_Model.history['val_accuracy']

  def plot_results(self):
    plt.plot(self.model_history.history['accuracy'])
    plt.plot(self.model_history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    plt.plot(self.model_history.history['loss'])
    plt.plot(self.model_history.history['val_loss'])
    plt.title('model lossess')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()
 

  def Normalize(self):
      def normalize_img(image, label):
        return tf.cast(image, tf.float32) / 255., label

      self.train_data = dataTrain.map(
          normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
      self.train_data= self.train_data.cache()
      # dataTrain_1 = dataTrain_1.shuffle(info.splits['train'].num_examples)
      self.train_data = self.train_data.batch(64)
      self.train_data = self.train_data.prefetch(tf.data.AUTOTUNE)

      self.test_data = dataTest.map(
          normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
      self.test_data = self.test_data.batch(64)
      self.test_data = self.test_data.prefetch(tf.data.AUTOTUNE)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/cifar10/3.0.2.incomplete5AKHCZ/cifar10-train.tfrecord*...:   0%|          | 0/…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/cifar10/3.0.2.incomplete5AKHCZ/cifar10-test.tfrecord*...:   0%|          | 0/1…
# Dataset cifar10 downloaded and prepared to ~/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %%
#ANN Network development Class
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

dataset = pd.read_csv('/content/drive/MyDrive/Churn_Modelling.csv')
X = dataset.iloc[:, 3:-1].values
y = dataset.iloc[:, -1].values

#Label Encoding Gender Colmun
le = LabelEncoder()
X[:, 2] = le.fit_transform(X[:, 2])

ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

class ANN:
  
  def __init__(self):
    
    self.model2 =  keras.Sequential()
    self.X_train=None
    self.X_test=None
    self.y_train=None
    self.y_test=None

  def get_test_train_data_split(self,split_ratio=0.2):
    self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(X, y, test_size = split_ratio, random_state = 0)
    self.X_train = sc.fit_transform(self.X_train)
    self.X_test = sc.transform(self.X_test)  

  #Method to make input layer
  def add_Input_and_FHL(self,neurons=12,activation_func='relu'):
     self.model2.add(keras.layers.Dense(units=neurons, activation=activation_func, input_shape=self.X_train[0].shape))
   
  def add_layer_Dense(self,neuronsNum=64,activation_func='relu'):
    self.model2.add(keras.layers.Dense(neuronsNum,activation=activation_func))
 
  def summary_model(self):
    self.model2.summary()

  def model_train_test(self,Batch_Size=32,Epoch_No=100):
    self.model2.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    #global history_Model
    self.history_Model=self.model2.fit(self.X_train,self.y_train, batch_size = Batch_Size, epochs = Epoch_No,validation_data=(self.X_test,self.y_test))
    # self.history_Model=self.model1.fit(self.test_data,batch_size=64,epochs=10,verbose=2,validation_data=self.train_data)
  def model_Predict(self,Array,Threshold):    
    return (self.model2.predict(sc.transform([Array]))> Threshold)
  def model_trained_history_info(self):
     return self.history_Model.history['accuracy'],self.history_Model.history['val_accuracy'],self.history_Model.history['loss'],self.history_Model.history['val_loss']

# %%
# app = Flask(__name__)
ngrok.set_auth_token("2IiNU67bA6e20hL5l1K6VgTPvo3_HqwTrAXo8zunSkDP6iWt")

app = Flask(__name__,template_folder='/content/drive/My Drive/template')
bootstrap=Bootstrap(app)
run_with_ngrok(app)

#Variable to interact with the 
global Com_Data

@app.route("/")
def home():      
      return render_template('index1.html',xAxis=[0],TnACU=[0],TsACU=[0])

#A model formation selected here
@app.route('/modelTypeSelect',methods=['POST'])
def modelTypeSelect():    
    select=request.form['model']
    global Com_Data
    Com_Data=""
    display=""
    if select=="Classification":
      global Classifier
      Classifier=automl()
      display="true" 
    else:
      global ANN_Network_Reg
      display="false"
      ANN_Network_Reg=ANN() 
    final_input=select
  
    Com_Data='<div>Selected {}</div>'.format(final_input)  
    return render_template('index1.html', output=Com_Data,display_Control=display,xAxis=[0],TnACU=[0],TsACU=[0])

#Input layer adding API
@app.route('/addInputLayer',methods=['POST'])
def addInputLayer():
    shape=int(request.form['width']),int(request.form['height']),int(request.form['channels'])
    Classifier.add_layer_Input(shape)
    Classifier.summary_model()
    global Com_Data
    Com_Data1='<div>Input layer added shape {}</div>'.format(shape)    
    Com_Data=Com_Data+Com_Data1
    return render_template('index1.html', output=Com_Data,display_Control="true",xAxis=[0],TnACU=[0],TsACU=[0])

@app.route('/Conv2DLayer',methods=['POST'])
def Conv2DLayer():
   kernel=int(request.form['kernel'])
   filters=int(request.form['filters'])
   activation=request.form['activation']
   kernel=(kernel,kernel)
   padding=request.form['Padding']
   Classifier.add_layer_Conv2D(filters,kernel,activation,padding)
   Classifier.summary_model()
   global Com_Data 
   Com_Data1='<div>Convlution layer added filter {} kernel {} activation {} padding {}</div>'.format(filters,kernel,activation,padding)
   Com_Data=Com_Data+Com_Data1
   return render_template('index1.html', output=Com_Data,display_Control="true",xAxis=[0],TnACU=[0],TsACU=[0])

@app.route('/FlattenLayer',methods=['POST'])
def FlattenLayer():    
   Classifier.add_layer_Flatten()
   Classifier.summary_model() 
   global Com_Data 
   Com_Data1='<div>Flattened layer added</div>'
   Com_Data=Com_Data+Com_Data1
   return render_template('index1.html', output=Com_Data,display_Control="true",xAxis=[0],TnACU=[0],TsACU=[0])


@app.route('/addMaxPool',methods=['POST'])
def addMaxPool():
   shape=int(request.form['width']),int(request.form['height'])    
   Classifier.add_layer_MaxPooling2D(shape)
   Classifier.summary_model() 
   global Com_Data 
   Com_Data1='<div>Maxpool layer added Kernel shape {}</div>'.format(shape)
   Com_Data=Com_Data+Com_Data1
   return render_template('index1.html', output=Com_Data,display_Control="true",xAxis=[0],TnACU=[0],TsACU=[0])

@app.route('/TrainModel',methods=['POST'])
def TrainModel():
   Epochs=int(request.form['Epochs'])
  #  Batch_Size=int(request.form['BatchSize'])    
   Classifier.Normalize()
   accuracy,val_accuracy=Classifier.model_train_test() 
   return render_template('index1.html', output='<div>Model Trained</div>',display_Control="true",xAxis=[0],TnACU=accuracy,TsACU=val_accuracy)

@app.route('/denselayer',methods=['POST'])
def denselayer():
   neurons=int(request.form['neurons'])
   activation=request.form['activation']   
   Classifier.add_layer_Dense(neurons,activation)
   Classifier.summary_model() 
   global Com_Data 
   Com_Data1='<div>Dense layer added Neurons {} Activation {}</div>'.format(neurons,activation)
   Com_Data=Com_Data+Com_Data1
   return render_template('index1.html', output=Com_Data,display_Control="true",xAxis=[0],TnACU=[0],TsACU=[0])


#Regression via ANN

@app.route('/addInputNFHNLayer',methods=['POST'])
def addInputNFHNLayer():
   neurons=int(request.form['neurons'])
   activation=request.form['activation']
   ANN_Network_Reg.add_Input_and_FHL(neurons,activation)   
   ANN_Network_Reg.summary_model() 
   global Com_Data 
   Com_Data1='<div> Added Input and Fist Hidden layer with Neurons {} Activation {}</div>'.format(neurons,activation)
   Com_Data=Com_Data+Com_Data1
   return render_template('index1.html', output=Com_Data,display_Control="false",xAxis=[0],TnACU=[0],TsACU=[0])

#Data Spliting
@app.route('/dataSplit',methods=['POST'])
def dataSplit():
   SP_ratio=float(request.form['SplitRatio'])
   ANN_Network_Reg.get_test_train_data_split(SP_ratio)
   global Com_Data 
   Com_Data1='<div> Data set Splitted with ratio of test data {}</div>'.format(SP_ratio)
   Com_Data=Com_Data+Com_Data1
   return render_template('index1.html', output=Com_Data,display_Control="false",xAxis=[0],TnACU=[0],TsACU=[0])

#Dense Layer addition
@app.route('/addDenselayerANN',methods=['POST'])
def addDenselayerANN():
   neurons=int(request.form['neurons'])
   activation=request.form['activation']
   ANN_Network_Reg.add_layer_Dense(neurons,activation)
   ANN_Network_Reg.summary_model() 
   global Com_Data 
   Com_Data1='<div> Added a layer with Neurons {} Activation {}</div>'.format(neurons,activation)
   Com_Data=Com_Data+Com_Data1
   return render_template('index1.html', output=Com_Data,display_Control="false",xAxis=[0],TnACU=[0],TsACU=[0])

#Model training API
@app.route('/TrainModel_Reg',methods=['POST'])
def TrainModel_Reg():
   Epochs=int(request.form['Epochs'])
   Batch_Size=int(request.form['BatchSize'])    
   ANN_Network_Reg.model_train_test(Batch_Size,Epochs)
   x=np.arange(Epochs)
   Training_auc,Test_auc,Train_loss,Test_loss=ANN_Network_Reg.model_trained_history_info()
   return render_template('index1.html', output='<div>Model Trained</div>',display_Control="false",xAxis=x,plotSh="show",TnACU=Training_auc,TsACU=Test_auc)

#Predictio of Linear Regression
@app.route('/predictValue',methods=['POST'])
def predictValue():
   Geopraphy=request.form['Geography']
   if Geopraphy=="france":
     a,b,c=1.0,0.0,0.0
   elif Geopraphy=="spain":
     a,b,c=0.0,0.0,1.0  
   elif Geopraphy=="germany":
     a,b,c=0.0,1.0,0.0
   CreditScore=float(request.form['CreditScore'])
   Gender=float(request.form['Gender'])
   age=float(request.form['age'])
   tenure=float(request.form['tenure'])
   balance=float(request.form['balance'])
   NBproduct=float(request.form['NBproduct'])
   CaditCardInfo=float(request.form['CaditCardInfo'])
   ACmem=float(request.form['MemberShipInfo'])
   EsSalary=float(request.form['EsSalary'])
   predict_array=[a,b,c,CreditScore,Gender,age,tenure,balance,NBproduct,CaditCardInfo,ACmem,EsSalary]
   global Com_Data
  #  predict_array= [0, 0, 1, 600, 1, 40, 3, 60000, 2, 1, 1, 50000]
   predicted=ANN_Network_Reg.model_Predict(predict_array,0.5)
  #  print(predict_array)
   Com_Data1='<div> Prediction of Exited is {}</div>'.format(predicted)
  #  Com_Data=Com_Data+Com_Data1
   return render_template('index1.html', output=Com_Data1,display_Control="false",xAxis=[0],TnACU=[0],TsACU=[0])

app.config['JSONIFY_PRETTYPRINT_REGULAR'] = False
app.run()
# Out:
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://1169-34-87-42-19.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [01/Jan/2023 06:08:01] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Jan/2023 06:08:03] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [01/Jan/2023 06:08:08] "POST /modelTypeSelect HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Jan/2023 06:08:12] "POST /dataSplit HTTP/1.1" 200 -
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 19)                247
#
# ...
# Total params: 247
# Trainable params: 247
# Non-trainable params: 0
# _________________________________________________________________
# INFO:werkzeug:127.0.0.1 - - [01/Jan/2023 06:08:22] "POST /addInputNFHNLayer HTTP/1.1" 200 -
# Model: "sequential_5"
# ...
